# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 了解 Dcard API 使用方式與回傳內容
# * 撰寫程式存取 API 且解析 JSON 格式資料

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
import requests
r = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
response = r.text

response

import json
data = json.loads(response)
count = 0
for d in data:
    count+=1

print(count)
# Out:
# 30

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
for d in data:
    print("標題:",d['title'])
    print("貼文時間:",d['createdAt'])
    print("留言人數:",d['commentCount'])
    print("按讚人數:",d['likeCount'])
# Out:
# 標題: 兄day你怎麼變這樣
# 貼文時間: 2020-03-04T14:12:22.188Z
# 留言人數: 44
# 按讚人數: 2430
# 標題: 一束貓也太可愛了吧！
# 貼文時間: 2020-03-04T14:20:38.948Z
# 留言人數: 16
# 按讚人數: 748
# 標題: 不當演員可惜了
# 貼文時間: 2020-03-04T13:24:51.655Z
# 留言人數: 41
# 按讚人數: 566
# 標題: 蝦皮上賣小動物 麻煩幫檢舉
# 貼文時間: 2020-03-05T02:54:11.596Z
# 留言人數: 47
# 按讚人數: 427
# 標題: 同學我需要妳的貓來撫慰心靈
# 貼文時間: 2020-03-04T09:52:05.983Z
# 留言人數: 11
# 按讚人數: 329
# 標題: 再說我認真魔人 小心我噴死妳
# 貼文時間: 2020-03-04T12:07:14.145Z
# 留言人數: 26
# 按讚人數: 228
# 標題: 爬蟲不可怕 可怕的是無知
# 貼文時間: 2020-03-04T17:47:34.104Z
# 留言人數: 23
# 按讚人數: 72
# 標題: 太可愛了！求原圖🥺
# 貼文時間: 2020-03-04T04:05:13.918Z
# 留言人數: 4
# 按讚人數: 56
# 標題: 養了12年的科基
# 貼文時間: 2020-03-04T16:48:55.262Z
# 留言人數: 6
# 按讚人數: 39
# 標題: 犬種介紹特輯3  極地登板 薩摩耶犬~(更)
# 貼文時間: 2020-03-04T15:57:25.482Z
# 留言人數: 17
# 按讚人數: 32
# 標題: 來蓋個黑貓樓吧
# 貼文時間: 2020-03-04T12:22:14.998Z
# 留言人數: 7
# 按讚人數: 27
# 標題: 不覺得貓眼睛超像一種食物的嗎？
# 貼文時間: 2020-03-04T17:25:47.611Z
# 留言人數: 2
# 按讚人數: 25
# 標題: #鼠 水喝光光終於懂事了🥺
# 貼文時間: 2020-03-05T05:44:00.479Z
# 留言人數: 3
# 按讚人數: 22
# 標題: 我家的貓愛上了我的電腦 該拆散還是祝福？
# 貼文時間: 2020-03-05T08:19:17.141Z
# 留言人數: 3
# 按讚人數: 17
# 標題: 枕邊不是人
# 貼文時間: 2020-03-04T15:37:42.292Z
# 留言人數: 5
# 按讚人數: 17
# 標題: #問 貓粉刺問題
# 貼文時間: 2020-03-05T02:51:19.610Z
# 留言人數: 13
# 按讚人數: 14
# 標題: 走失鸚鵡😢
# 貼文時間: 2020-03-04T18:40:56.691Z
# 留言人數: 0
# 按讚人數: 13
# 標題: #影片 乾 你真的沒資格養貓跟當人
# 貼文時間: 2020-03-05T10:04:45.244Z
# 留言人數: 3
# 按讚人數: 12
# 標題: 待在收容所6年的餅餅 找一個家
# 貼文時間: 2020-03-05T04:40:56.797Z
# 留言人數: 0
# 按讚人數: 12
# 標題: 黑色土狗領養
# 貼文時間: 2020-03-04T16:36:15.022Z
# 留言人數: 2
# 按讚人數: 12
# 標題: 寵物圖卡來襲❤️
# 貼文時間: 2020-03-04T12:55:05.985Z
# 留言人數: 6
# 按讚人數: 12
# 標題: 我的哈雷，各個都是她的好朋友，請問大家的小猫也會這樣嗎？完全不怕生，希望這個性可以伴隨她一起長大😬先讓大家看看她可愛的模樣，因為長大就換路線了
# 貼文時間: 2020-03-04T06:53:04.433Z
# 留言人數: 6
# 按讚人數: 11
# 標題: 貓咪只喜愛中高價位的主食罐
# 貼文時間: 2020-03-04T16:59:36.243Z
# 留言人數: 3
# 按讚人數: 10
# 標題: 嘎～
# 貼文時間: 2020-03-04T06:21:21.135Z
# 留言人數: 9
# 按讚人數: 9
# 標題: 怎麼沒有爬蟲版
# 貼文時間: 2020-03-04T17:10:31.097Z
# 留言人數: 17
# 按讚人數: 7
# 標題: 犬種介紹特輯4  始終如一 法國鬥牛犬~
# 貼文時間: 2020-03-05T12:31:24.912Z
# 留言人數: 2
# 按讚人數: 6
# 標題: 撿到鸚鵡
# 貼文時間: 2020-03-05T10:39:27.694Z
# 留言人數: 9
# 按讚人數: 6
# 標題: 貓咪社團的亂象
# 貼文時間: 2020-03-04T18:45:55.740Z
# 留言人數: 9
# 按讚人數: 6
# 標題: 請益 貓可以吃銀柳葉嗎？
# 貼文時間: 2020-03-04T13:48:15.754Z
# 留言人數: 1
# 按讚人數: 6
# 標題: 我的龜龜受傷了ㅠㅠ
# 貼文時間: 2020-03-05T13:46:01.535Z
# 留言人數: 1
# 按讚人數: 5

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」
abc=0
bcd=0
count=0
for d in data:
    abc+=d['commentCount']
    bcd+=d['likeCount']
    count+=1
print('平均留言人數')
print(abc/count)
print('平均按讚人數')
print(bcd/count)
# Out:
# 平均留言人數
# 11.2
# 平均按讚人數
# 172.53333333333333
